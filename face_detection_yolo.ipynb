# %% [markdown]
# <a href="https://colab.research.google.com/github/willyptrain/cs4774-mask-detection/blob/main/face_detection_yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Machine Learning Homework 4 - Image Classification

__author__ = 'wcp7cp'

# General imports
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.model_selection import GridSearchCV
import os
import sys
import pandas as pd

# Keras
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten
from keras.wrappers.scikit_learn import KerasClassifier

import scipy.io as sio
import matplotlib.patches as patches
from PIL import Image
import numpy as np
import cv2

# %%
yolo_weights = "/content/drive/My Drive/yolov3.weights"
yolo_cfg = "/content/drive/My Drive/wider_face_yolov3.cfg"
object_data = "/content/drive/My Drive/obj.data"
train_annotations  = "/content/drive/My Drive/train_annotations.txt"
valid_annotations  = "/content/drive/My Drive/val_annotations.txt"
train_files = "/content/drive/My Drive/train_files.txt"
val_files = "/content/drive/My Drive/val_files.txt"

# !cp "/content/drive/My Drive/obj.data" "darknet/data/"
# !cp "/content/drive/My Drive/train_files.txt" "darknet/data/"
# !cp "/content/drive/My Drive/val_files.txt" "darknet/data/"
# !unzip 'drive/My Drive/WIDER_train' 
# !unzip 'drive/My Drive/WIDER_val' 
# !unzip 'drive/My Drive/WIDER_test'
# !mv '/content/WIDER_train' "darknet/data/"
# !mv '/content/WIDER_val' "darknet/data/"


# !cp 'drive/My Drive/WIDER_test'

# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# !make

# %cd darknet/
# !./darknet detector train "../drive/My Drive/obj.data" "../drive/My Drive/wider_face_yolov3.cfg" "../drive/My Drive/yolov3.weights"
# %cd ..
# Out:
# /content/darknet
#  GPU isn't used
#  OpenCV isn't used - data augmentation will be slow
# wider_face_yolov3
# mini_batch = 4, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#   12 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
#   13 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   14 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   17 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   20 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   23 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   26 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   29 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   32 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   35 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
#   38 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   39 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   41 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   42 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   44 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   45 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   47 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   48 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   50 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   51 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   53 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   54 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   57 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   59 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   60 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   62 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
#   63 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   64 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   67 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   70 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   73 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   76 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   77 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   78 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   79 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   80 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   81 conv     18       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x  18 0.006 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   13 x  13 x 512
#   84 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   85 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
#   86 route  85 61 	                           ->   26 x  26 x 768
#   87 conv    256       1 x 1/ 1     26 x  26 x 768 ->   26 x  26 x 256 0.266 BF
#   88 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   89 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   90 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   91 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   92 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   93 conv     18       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x  18 0.012 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   26 x  26 x 256
#   96 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#   97 upsample                 2x    26 x  26 x 128 ->   52 x  52 x 128
#   98 route  97 36 	                           ->   52 x  52 x 384
#   99 conv    128       1 x 1/ 1     52 x  52 x 384 ->   52 x  52 x 128 0.266 BF
#  100 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  101 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  102 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  103 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  104 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  105 conv     18       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x  18 0.025 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 65.304
# avg_outputs = 516723
# Loading weights from ../drive/My Drive/yolov3.weights...
#  seen 64, trained: 32013 K-images (500 Kilo-batches_64)
# Done! Loaded 107 layers from weights-file
# Learning Rate: 0.001, Momentum: 0.9, Decay: 0.0005
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# Saving weights to backup/wider_face_yolov3_final.weights
#  Create 64 permanent cpu-threads
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/13--Interview/13_Interview_Interview_Sequences_13_542.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/2--Demonstration/2_Demonstration_Demonstration_Or_Protest_2_299.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/55--Sports_Coach_Trainer/55_Sports_Coach_Trainer_sportcoaching_55_813.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/2--Demonstration/2_Demonstration_Protesters_2_325.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/28--Sports_Fan/28_Sports_Fan_Sports_Fan_28_371.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/2--Demonstration/2_Demonstration_Protesters_2_445.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/48--Parachutist_Paratrooper/48_Parachutist_Paratrooper_Parachutist_Paratrooper_48_343.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/40--Gymnastics/40_Gymnastics_Gymnastics_40_850.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/7--Cheering/7_Cheering_Cheering_7_547.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/22--Picnic/22_Picnic_Picnic_22_455.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/23--Shoppers/23_Shoppers_Shoppers_23_736.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/36--Football/36_Football_americanfootball_ball_36_842.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/0--Parade/0_Parade_marchingband_1_19.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/0--Parade/0_Parade_marchingband_1_219.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/52--Photographers/52_Photographers_photographertakingphoto_52_401.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/24--Soldier_Firing/24_Soldier_Firing_Soldier_Firing_24_60.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/2--Demonstration/2_Demonstration_Demonstrators_2_44.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/13--Interview/13_Interview_Interview_On_Location_13_311.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/6--Funeral/6_Funeral_Funeral_6_1010.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/33--Running/33_Running_Running_33_226.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/56--Voter/56_Voter_peoplevoting_56_271.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/49--Greeting/49_Greeting_peoplegreeting_49_8.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/18--Concerts/18_Concerts_Concerts_18_308.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/0--Parade/0_Parade_Parade_0_185.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/35--Basketball/35_Basketball_basketballgame_ball_35_92.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/5--Car_Accident/5_Car_Accident_Car_Crash_5_265.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/2--Demonstration/2_Demonstration_Protesters_2_734.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/0--Parade/0_Parade_marchingband_1_19.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/2--Demonstration/2_Demonstration_Protesters_2_162.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/20--Family_Group/20_Family_Group_Family_Group_20_388.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/50--Celebration_Or_Party/50_Celebration_Or_Party_houseparty_50_32.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/4--Dancing/4_Dancing_Dancing_4_355.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/12--Group/12_Group_Group_12_Group_Group_12_163.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_693.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/48--Parachutist_Paratrooper/48_Parachutist_Paratrooper_Parachutist_Paratrooper_48_664.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/37--Soccer/37_Soccer_soccer_ball_37_880.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/0--Parade/0_Parade_marchingband_1_632.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/52--Photographers/52_Photographers_photographertakingphoto_52_318.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/37--Soccer/37_Soccer_soccer_ball_37_273.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_317.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/0--Parade/0_Parade_marchingband_1_200.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/39--Ice_Skating/39_Ice_Skating_iceskiing_39_303.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/1--Handshaking/1_Handshaking_Handshaking_1_165.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/2--Demonstration/2_Demonstration_Demonstrators_2_399.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/59--people--driving--car/59_peopledrivingcar_peopledrivingcar_59_914.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/55--Sports_Coach_Trainer/55_Sports_Coach_Trainer_sportcoaching_55_877.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/30--Surgeons/30_Surgeons_Surgeons_30_886.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/25--Soldier_Patrol/25_Soldier_Patrol_Soldier_Patrol_25_793.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/15--Stock_Market/15_Stock_Market_Stock_Market_15_380.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/47--Matador_Bullfighter/47_Matador_Bullfighter_Matador_Bullfighter_47_212.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/31--Waiter_Waitress/31_Waiter_Waitress_Waiter_Waitress_31_850.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/51--Dresses/51_Dresses_wearingdress_51_668.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/4--Dancing/4_Dancing_Dancing_4_860.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/23--Shoppers/23_Shoppers_Shoppers_23_559.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/22--Picnic/22_Picnic_Picnic_22_755.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/59--people--driving--car/59_peopledrivingcar_peopledrivingcar_59_369.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/5--Car_Accident/5_Car_Accident_Car_Crash_5_667.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/16--Award_Ceremony/16_Award_Ceremony_Awards_Ceremony_16_508.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/9--Press_Conference/9_Press_Conference_Press_Conference_9_475.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/41--Swimming/41_Swimming_Swimmer_41_844.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/0--Parade/0_Parade_marchingband_1_1046.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/45--Balloonist/45_Balloonist_Balloonist_45_882.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/56--Voter/56_Voter_peoplevoting_56_1021.txt
# Can't open label file. (This can be normal only if you use MSCOCO): data/WIDER_train/images/16--Award_Ceremony/16_Award_Ceremony_Awards_Ceremony_16_673.txt
# If you want to train from the beginning, then use flag in the end of training command: -clear
# /content

# %%
test_config = "../drive/My Drive/wider_face_yolov3.cfg"
test_weights = "darknet/backup/wider_face_yolov3_final.weights"

net = cv2.dnn.readNetFromDarknet(test_config, test_weights)
net.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
ln = net.getLayerNames()
print(len(ln), ln)
ln = [ln[i[0] - 1] for i in net.getUnconnectedOutLayers()]
print(ln)

img = cv2.resize(cv2.imread("/content/drive/My Drive/test_people.jpg"), (416,416))
blob = cv2.dnn.blobFromImage(img, 1/255.0, (416, 416), swapRB=True, crop=True)
r = blob[0, 0, :, :]

net.setInput(blob)
outputs = net.forward(ln)
plt.imshow(img)

#ADAPTED FROM: https://colab.research.google.com/drive/1dYwDAjSgzj_9MQEZ4Uu3nR_9K-4zlsqQ#scrollTo=Bn95xJWPL63i
def yolo(img):
    coco = "/content/drive/My Drive/coco.names"
    LABELS = open(coco).read().strip().split("\n")
    COLORS = np.random.randint(0, 255, size=(len(LABELS), 3),dtype="uint8")

    blob = cv2.dnn.blobFromImage(img, 1 / 255.0, (416, 416),
        swapRB=True, crop=True)
    net.setInput(blob)
    layerOutputs = net.forward(ln)


    h_img = img.shape[0]
    w_img = img.shape[1]

    boxes = []
    confidences = []
    classIDs = []

    print(layerOutputs)

    for output in layerOutputs:
        for detection in output:

            scores = detection[5:]
            classID = np.argmax(scores)
            confidence = scores[classID]

            if confidence > .5:
                print(LABELS[classID], confidence)
   
                box = detection[0:4] * np.array([w_img, h_img, w_img, h_img])
                (centerX, centerY, w, h) = box.astype("int")

                x = int(centerX - (w / 2))
                y = int(centerY - (h / 2))

                print(x, y, int(w), int(h))
                boxes.append([x, y, int(w), int(h)])
                confidences.append(float(confidence))
                classIDs.append(classID)

    idxs = cv2.dnn.NMSBoxes(boxes, confidences, .5, .4 )
    if len(idxs) > 0:
        fig,ax = plt.subplots(1)
        ax.imshow(img)
        for i in idxs.flatten():
            (x, y) = (boxes[i][0], boxes[i][1])
            (w, h) = (boxes[i][2], boxes[i][3])
            color = [int(c) for c in COLORS[classIDs[i]]]
            cv2.rectangle(img, (x, y), (x + w, y + h), color, 2)
            rect = patches.Rectangle((x,y),x+w,y+h,linewidth=1,edgecolor='r',facecolor='none')
            ax.add_patch(rect)
            
        plt.show()

yolo(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-56-6b699e74a6bb> in <module>()
#       3 test_weights = "darknet/backup/wider_face_yolov3_final.weights"
#       4
# ----> 5 net = cv2.dnn.readNetFromDarknet(test_config, test_weights)
#       6 net.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
#       7 ln = net.getLayerNames()
#
# error: OpenCV(4.1.2) /io/opencv/modules/dnn/src/darknet/darknet_importer.cpp:207: error: (-212:Parsing error) Failed to parse NetParameter file: ../drive/My Drive/wider_face_yolov3.cfg in function 'readNetFromDarknet'
